# %% [markdown]
# <a href="https://colab.research.google.com/github/minaremeli/EquivalentPerturbations/blob/master/demos/RunTestAttack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/minaremeli/EquivalentPerturbations.git
# Out:
# Cloning into 'EquivalentPerturbations'...
# remote: Enumerating objects: 261, done.
# remote: Counting objects: 100% (261/261), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 261 (delta 51), reused 244 (delta 41), pack-reused 0
# Receiving objects: 100% (261/261), 2.86 MiB | 14.71 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
# !python -c "import torch; print(torch.__version__)"
# Out:
# 1.10.0+cu111

# %%
# !python -c "import torch; print(torch.version.cuda)"
# Out:
# 11.1

# %%
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-1.10.0+cu111.html
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-1.10.0+cu111.html
# !pip install torch-geometric
# !pip install deeprobust
# Out:
# Looking in links: https://data.pyg.org/whl/torch-1.10.0+cu111.html
# ...
#      |████████████████████████████████| 7.9 MB 776 kB/s
# ...
# Looking in links: https://data.pyg.org/whl/torch-1.10.0+cu111.html
# ...
#      |████████████████████████████████| 3.5 MB 12.9 MB/s
# ...
#      |████████████████████████████████| 407 kB 14.2 MB/s
# ...
#   Created wheel for torch-geometric: filename=torch_geometric-2.0.4-py3-none-any.whl size=616603 sha256=ef3fd30e2dcb3f207895e99138e8e28fb35478535cd89c85b0a300eb3ab35863
#   Stored in directory: /root/.cache/pip/wheels/18/a6/a4/ca18c3051fcead866fe7b85700ee2240d883562a1bc70ce421
# Successfully built torch-geometric
# ...

# %%
# %cd EquivalentPerturbations/DeepRobust/
# !python setup.py install
# %cd ../..
# Out:
# /content/EquivalentPerturbations/DeepRobust
# running install
# running bdist_egg
# running egg_info
# creating deeprobust.egg-info
# writing deeprobust.egg-info/PKG-INFO
# writing dependency_links to deeprobust.egg-info/dependency_links.txt
# writing requirements to deeprobust.egg-info/requires.txt
# writing top-level names to deeprobust.egg-info/top_level.txt
# writing manifest file 'deeprobust.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'deeprobust.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/deeprobust
# copying deeprobust/__init__.py -> build/lib/deeprobust
# creating build/lib/deeprobust/graph
# copying deeprobust/graph/utils.py -> build/lib/deeprobust/graph
# copying deeprobust/graph/black_box.py -> build/lib/deeprobust/graph
# copying deeprobust/graph/visualization.py -> build/lib/deeprobust/graph
# ...

# %%
# !python test_attack.py
# Out:
# cuda: False
# Loading citeseer dataset...
# ...
# Done!
# Selecting 1 largest connected components
# Target node degree:  11
# ##### Starting attack #####
# ##### Attack only using structure perturbations #####
# ##### Attacking the node directly #####
# ##### Performing 13 perturbations #####
# ##### ...1/13 perturbations ... #####
# /usr/local/lib/python3.7/dist-packages/numba/core/ir_utils.py:2031: NumbaPendingDeprecationWarning:
# Encountered the use of a type that is scheduled for deprecation: type 'reflected set' found for argument 'edges_set' of function 'compute_new_a_hat_uv'.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-reflection-for-list-and-set-types
#
# File "../usr/local/lib/python3.7/dist-packages/deeprobust-0.2.3-py3.7.egg/deeprobust/graph/targeted_attack/nettack.py", line 500:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(NumbaPendingDeprecationWarning(msg, loc=loc))
# ...
